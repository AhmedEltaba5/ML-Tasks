# %% [markdown]
# ![mining-the-web.jpg](attachment:mining-the-web.jpg)

# %% [markdown]
# Link to article in medium: https://medium.com/analytics-vidhya/semantic-search-engine-using-nlp-cec19e8cfa7e

# %% [markdown]
# # Introduction
#
# The World Wide Web has become colossal and its growth is also dynamic. Most of the people rely on the search engines to retrieve and share information from various resources. All the results returned by search engines are not always relevant as it is retrieved from heterogeneous data sources. Moreover a naive user finds it difficult to confirm that the retrieved results are significant to the user query.Therefore semantic web plays a major role in interpreting the relevancy of search results.
#
# In this work, we will retrieve relevant movie titles using semantic search based on the concept of Natural Language processing (NLP)

# %% [markdown]
# ## Keyword Search Vs Semantic Search
#
# At first, search engines were lexical: the search engine looked for literal matches of the query words, without understanding of the query’s meaning and only returning links that contained the exact query.By using regular keyword search, a document either contains the given word or not, and there is no middle ground
#
# On the other hand, "Semantic Search" can simplify query building, becuase it is supported by automated natural language processing programs i.e. using Latent Semantic Indexing - a concept that search engines use to discover how a keyword and content work together to mean the same thing.
#
# LSI adds an important step to the document indexing process. LSI examines a collection of documents to see which documents contain some of those same words. LSI considers documents that have many words in common to be semantically close, and ones with less words in common to be less close.
#
# In brief, LSI does not require an exact match to return useful results. Where a plain keyword search will fail if there is no exact match, LSI will often return relevant documents that don't contain the keyword at all.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import spacy
import string
import gensim
import operator
import re

# %% [markdown]
# ### Load the data
# We will now load the movies data csv into dataframe and quickly peek into the columns and data provided

# %%
df_movies = pd.read_csv('movies.csv')

# %%
pd.set_option('display.max_rows', 1000)
#pd.set_option('display.max_colwidth', 1000)

# %%
df_movies.head()
# Out:
#    rank                     title                                    genre  \
# 0     0             The Godfather                   [u' Crime', u' Drama']
# 1     1  The Shawshank Redemption                   [u' Crime', u' Drama']
# 2     2          Schindler's List  [u' Biography', u' Drama', u' History']
# 3     3               Raging Bull    [u' Biography', u' Drama', u' Sport']
# 4     4                Casablanca        [u' Drama', u' Romance', u' War']
#
#                                            wiki_plot  \
# 0  On the day of his only daughter's wedding, Vit...
# 1  In 1947, banker Andy Dufresne is convicted of ...
# 2  In 1939, the Germans move Polish Jews into the...
# 3  In a brief scene in 1964, an aging, overweight...
# 4  It is early December 1941. American expatriate...
#
#                                            imdb_plot
# 0  In late summer 1945, guests are gathered for t...
# 1  In 1947, Andy Dufresne (Tim Robbins), a banker...
# 2  The relocation of Polish Jews from surrounding...
# 3  The film opens in 1964, where an older and fat...
# 4  In the early years of World War II, December 1...

# %%
df_movies.shape
# Out:
# (100, 6)

# %%
df_movies['wiki_plot'][0]
# Out:
# 'On the day of his only daughter\'s wedding, Vito Corleone hears requests in his role as the Godfather, the Don of a New York crime family. Vito\'s youngest son, Michael, in a Marine Corps uniform, introduces his girlfriend, Kay Adams, to his family at the sprawling reception. Vito\'s godson Johnny Fontane, a popular singer, pleads for help in securing a coveted movie role, so Vito dispatches his consigliere, Tom Hagen, to Los Angeles to influence the abrasive studio head, Jack Woltz. Woltz is unmoved until the morning he wakes up in bed with the severed head of his prized stallion.  On the day of his only daughter\'s wedding,   Vito Corleone  Vito Corleone   hears requests in his role as the Godfather, the   Don  Don   of a New York crime family. Vito\'s youngest son,   Michael  Michael  , in a   Marine Corps  Marine Corps   uniform, introduces his girlfriend,   Kay Adams  Kay Adams  , to his family at the sprawling reception. Vito\'s godson   Johnny Fontane  Johnny Fontane  , a popular singer, pleads for help in securing a coveted movie role, so Vito dispatches his   consigliere  consigliere  ,   Tom Hagen  Tom Hagen  , to Los Angeles to influence the abrasive studio head,   Jack Woltz  Jack Woltz  . Woltz is unmoved until the morning he wakes up in bed with the severed head of his prized   stallion  stallion  .  \n  Shortly before Christmas 1945, drug baron Virgil "The Turk" Sollozzo, backed by the Corleones\' rivals, the Tattaglias, asks Vito for investment in the emerging drug trade and protection through his political connections. Vito disapproves of drug dealers, so he sends his enforcer, Luca Brasi, to spy on them. The family then receives two fish wrapped in Brasi\'s vest, imparting that he "sleeps with the fishes". An assassination attempt by Sollozzo\'s men lands Vito in the hospital, so his eldest son, Sonny, takes command. Sollozzo kidnaps Hagen to pressure Sonny to accept his deal. Michael thwarts a second assassination attempt on his father at the hospital; his jaw is broken by Police Captain McCluskey, who is also Sollozzo\'s bodyguard. Sonny retaliates for the attacks on his father by having Tattaglia\'s son killed. Michael comes up with a plan to hit Sollozzo and McCluskey: on the pretext of settling the dispute, Michael accepts their offer to meet in a Bronx restaurant and, retrieving a planted handgun, murders them.  Shortly before Christmas 1945, drug baron   Virgil "The Turk" Sollozzo  Virgil "The Turk" Sollozzo  , backed by the Corleones\' rivals, the Tattaglias, asks Vito for investment in the emerging drug trade and protection through his political connections. Vito disapproves of drug dealers, so he sends his enforcer,   Luca Brasi  Luca Brasi  , to spy on them. The family then receives two fish wrapped in Brasi\'s vest, imparting that he "sleeps with the fishes". An assassination attempt by Sollozzo\'s men lands Vito in the hospital, so his eldest son,   Sonny  Sonny  , takes command. Sollozzo kidnaps Hagen to pressure Sonny to accept his deal. Michael thwarts a second assassination attempt on his father at the hospital; his jaw is broken by Police Captain McCluskey, who is also Sollozzo\'s bodyguard. Sonny retaliates for the attacks on his father by having Tattaglia\'s son killed. Michael comes up with a plan to hit Sollozzo and McCluskey: on the pretext of settling the dispute, Michael accepts their offer to meet in a Bronx restaurant and, retrieving a planted handgun, murders them.  \n  Despite a clampdown from the authorities, the Five Families erupt in open warfare and the brothers fear for their safety. Michael takes refuge in Sicily, and Fredo Corleone is sheltered by associate Moe Greene in Las Vegas. Sonny attacks his brother-in-law Carlo on the street for abusing his sister Connie and threatens to kill him if he abuses her again. When it happens again, Sonny speeds for her home but assassins ambush him at a highway toll booth and riddle him with submachine gun fire. Michael\'s time abroad h ...

# %% [markdown]
# ### Data Cleaning and Pre-processing
# Data pre-processing is one of the most significant step in text analytics. The purpose is to remove any unwanted words or characters which are written for human readability, but won't contribute to topic modelling in anyway.
#
# The following function applies regular expression for matching patterns of unwanted text and removing/replacing them.

# %%
from spacy.lang.en.stop_words import STOP_WORDS

spacy_nlp = spacy.load('en_core_web_sm')

#create list of punctuations and stopwords
punctuations = string.punctuation
stop_words = spacy.lang.en.stop_words.STOP_WORDS

#function for data cleaning and processing
#This can be further enhanced by adding / removing reg-exps as desired.

def spacy_tokenizer(sentence):
 
    #remove distracting single quotes
    sentence = re.sub('\'','',sentence)

    #remove digits adnd words containing digits
    sentence = re.sub('\w*\d\w*','',sentence)

    #replace extra spaces with single space
    sentence = re.sub(' +',' ',sentence)

    #remove unwanted lines starting from special charcters
    sentence = re.sub(r'\n: \'\'.*','',sentence)
    sentence = re.sub(r'\n!.*','',sentence)
    sentence = re.sub(r'^:\'\'.*','',sentence)
    
    #remove non-breaking new line characters
    sentence = re.sub(r'\n',' ',sentence)
    
    #remove punctunations
    sentence = re.sub(r'[^\w\s]',' ',sentence)
    
    #creating token object
    tokens = spacy_nlp(sentence)
    
    #lower, strip and lemmatize
    tokens = [word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in tokens]
    
    #remove stopwords, and exclude words less than 2 characters
    tokens = [word for word in tokens if word not in stop_words and word not in punctuations and len(word) > 2]
    
    #return tokens
    return tokens

# %% [markdown]
# Now let us apply the data-cleaning and pre-processing function to our movies "wiki_plot" column and store the cleaned, tokenized data into new column

# %%
print ('Cleaning and Tokenizing...')
# %time df_movies['wiki_plot_tokenized'] = df_movies['wiki_plot'].map(lambda x: spacy_tokenizer(x))

df_movies.head()
# Out:
# Cleaning and Tokenizing...
# Wall time: 42 s
#    rank                     title                                    genre  \
# 0     0             The Godfather                   [u' Crime', u' Drama']
# 1     1  The Shawshank Redemption                   [u' Crime', u' Drama']
# 2     2          Schindler's List  [u' Biography', u' Drama', u' History']
# 3     3               Raging Bull    [u' Biography', u' Drama', u' Sport']
# 4     4                Casablanca        [u' Drama', u' Romance', u' War']
#
#                                            wiki_plot  \
# 0  On the day of his only daughter's wedding, Vit...
# 1  In 1947, banker Andy Dufresne is convicted of ...
# 2  In 1939, the Germans move Polish Jews into the...
# 3  In a brief scene in 1964, an aging, overweight...
# 4  It is early December 1941. American expatriate...
#
#                                            imdb_plot  \
# 0  In late summer 1945, guests are gathered for t...
# 1  In 1947, Andy Dufresne (Tim Robbins), a banker...
# 2  The relocation of Polish Jews from surrounding...
# 3  The film opens in 1964, where an older and fat...
# 4  In the early years of World War II, December 1...
#
#                                  wiki_plot_tokenized
# 0  [day, daughter, wedding, vito, corleone, hear,...
# 1  [banker, andy, dufresne, convict, murder, wife...
# 2  [germans, polish, jews, kraków, ghetto, world,...
# 3  [brief, scene, age, overweight, italian, ameri...
# 4  [early, december, american, expatriate, rick, ...

# %% [markdown]
# Store the tokenized column into a sepearte variable for ease of operations in subsequent sections and have a quick peek into the values

# %%
movie_plot = df_movies['wiki_plot_tokenized']
movie_plot[0:5]
# Out:
# 0    [day, daughter, wedding, vito, corleone, hear,...
# 1    [banker, andy, dufresne, convict, murder, wife...
# 2    [germans, polish, jews, kraków, ghetto, world,...
# 3    [brief, scene, age, overweight, italian, ameri...
# 4    [early, december, american, expatriate, rick, ...
# Name: wiki_plot_tokenized, dtype: object

# %%
movie_plot[0]
# Out:
# ['day',
#  'daughter',
#  'wedding',
#  'vito',
#  'corleone',
#  'hear',
#  'request',
#  'role',
#  'godfather',
#  'don',
#  'new',
#  'york',
#  'crime',
#  'family',
#  'vitos',
#  'young',
#  'son',
#  'michael',
#  'marine',
#  'corps',
#  'uniform',
#  'introduce',
#  'girlfriend',
#  'kay',
#  'adams',
#  'family',
#  'sprawl',
#  'reception',
#  'vitos',
#  'godson',
#  'johnny',
#  'fontane',
#  'popular',
#  'singer',
#  'plead',
#  'help',
#  'secure',
#  'coveted',
#  'movie',
#  'role',
#  'vito',
#  'dispatch',
#  'consigliere',
#  'tom',
#  'hagen',
#  'los',
#  'angeles',
#  'influence',
#  'abrasive',
#  'studio',
#  'head',
#  'jack',
#  'woltz',
#  'woltz',
#  'unmove',
#  'morning',
#  'wake',
#  'bed',
#  'sever',
#  'head',
#  'prized',
#  'stallion',
#  'day',
#  'daughter',
#  'wedding',
#  'vito',
#  'corleone',
#  'vito',
#  'corleone',
#  'hear',
#  'request',
#  'role',
#  'godfather',
#  'don',
#  'don',
#  'new',
#  'york',
#  'crime',
#  'family',
#  'vitos',
#  'young',
#  'son',
#  'michael',
#  'michael',
#  'marine',
#  'corps',
#  'marine',
#  'corps',
#  'uniform',
#  'introduce',
#  'girlfriend',
#  'kay',
#  'adams',
#  'kay',
#  'adams',
#  'family',
#  'sprawl',
#  'reception',
#  'vitos',
#  'godson',
#  'johnny',
#  'fontane',
#  'johnny',
#  'fontane',
#  'popular',
#  'singer',
#  'plead',
#  'help',
#  'secure',
#  'coveted',
#  'movie',
#  'role',
#  'vito',
#  'dispatch',
#  'consigliere',
#  'consigliere',
#  'tom',
#  'hagen',
#  'tom',
#  'hagen',
#  'los',
#  'angeles',
#  'influence',
#  'abrasive',
#  'studio',
#  'head',
#  'jack',
#  'woltz',
#  'jack',
#  'woltz',
#  'woltz',
#  'unmove',
#  'morning',
#  'wake',
#  'bed',
#  'sever',
#  'head',
#  'prize',
#  'stallion',
#  'stallion',
#  'shortly',
#  'christmas',
#  'drug',
#  'baron',
#  'virgil',
#  'turk',
#  'sollozzo',
#  'corleones',
#  'rival',
#  'tattaglias',
#  'ask',
#  'vito',
#  'investment',
#  'emerge',
#  'drug',
#  'trade',
#  'protection',
#  'political',
#  'connection',
#  'vito',
#  'disapprove',
#  'drug',
#  'dealer',
#  'send',
#  'enforcer',
#  'luca',
#  'brasi',
#  'spy',
#  'family',
#  'receive',
#  'fish',
#  'wrap',
#  'brasis',
#  'vest',
#  'impart',
#  'sleep',
#  'fish',
#  'assassination',
#  'attempt',
#  'sollozzos',
#  'man',
#  'land',
#  'vito',
#  'hospital',
#  'eld',
#  'son',
#  'sonny',
#  'command',
#  'sollozzo',
#  'kidnap',
#  'hagen',
#  'pressure',
#  'sonny',
#  'accept',
#  'deal',
#  'michael',
#  'thwart',
#  'second',
#  'assassination',
#  'attempt',
#  'father',
#  'hospital',
#  'jaw',
#  'break',
#  'police',
#  'captain',
#  'mccluskey',
#  'sollozzos',
#  'bodyguard',
#  'sonny',
#  'retaliate',
#  'attack',
#  'father',
#  'tattaglias',
#  'son',
#  'kill',
#  'michael',
#  'come',
#  'plan',
#  'hit',
#  'sollozzo',
#  'mccluskey',
#  'pretext',
#  'settle',
#  'dispute',
#  'michael',
#  'accept',
#  'offer',
#  'meet',
#  'bronx',
#  'restaurant',
#  'retrieve',
#  'plant',
#  'handgun',
#  'murder',
#  'shortly',
#  'christmas',
#  'drug',
#  'baron',
#  'virgil',
#  'turk',
#  'sollozzo',
#  'virgil',
#  'turk',
#  'sollozzo',
#  'corleones',
#  'rival',
#  'tattaglias',
#  'ask',
#  'vito',
#  'investment',
#  'emerge',
#  'drug',
#  'trade',
#  'protection',
#  'political',
#  'connection',
#  'vito',
#  'disapprove',
#  'drug',
#  'dealer',
#  'send',
#  'enforcer',
#  'luca',
#  'brasi',
#  'luca',
#  'brasi',
#  'spy',
#  'family',
#  'receive',
#  'fish',
#  'wrap',
#  'brasis',
#  'vest',
#  'impart',
#  'sleep',
#  'fish',
#  'assassination',
#  'attempt',
#  'sollozzos',
#  'man',
#  'land',
#  'vito',
#  'hospital',
#  'eld',
#  'son',
#  'sonny',
#  'sonny',
#  'command',
#  'sollozzo',
#  'kidnap',
#  'hagen',
#  'pressure',
#  'sonny',
#  'accept',
#  'deal',
#  'michael',
#  'thwart',
#  'second',
#  'assassination',
#  'attempt',
#  'father',
#  'hospital',
#  'jaw',
#  'break',
#  'police',
#  'captain',
#  'mccluskey',
#  'sollozzos',
#  'bodyguard',
#  'sonny',
#  'retaliate',
#  'attack',
#  'father',
#  'tattaglias',
#  'son',
#  'kill',
#  'michael',
#  'come',
#  'plan',
#  'hit',
#  'sollozzo',
#  'mccluskey',
#  'pretext',
#  'settle',
#  'dispute',
#  'michael',
#  'accept',
#  'offer',
#  'meet',
#  'bronx',
#  'restaurant',
#  'retrieve',
#  'plant',
#  'handgun',
#  'murder',
#  'despite',
#  'clampdown',
#  'authority',
#  'families',
#  'erupt',
#  'open',
#  'warfare',
#  'brother',
#  'fear',
#  'safety',
#  'michael',
#  'refuge',
#  'sicily',
#  'fredo',
#  'corleone',
#  'shelter',
#  'associate',
#  'moe',
#  'greene',
#  'las',
#  'vegas',
#  'sonny',
#  'attack',
#  'brother',
#  'law',
#  'carlo',
#  'street',
#  'abuse',
#  'sister',
#  'connie',
#  'threaten',
#  'kill',
#  'abuse',
#  'happen',
#  'sonny',
#  'speed',
#  'home',
#  'assassin',
#  'ambush',
#  'highway',
#  'toll',
#  'booth',
#  'riddle',
#  'submachine',
#  'gun',
#  'fire',
#  'michaels',
#  'time',
#  'abroad',
#  'lead',
#  'marriage',
#  'apollonia',
#  'vitelli',
#  'euphoria',
#  'shatter',
#  'car',
#  'bomb',
#  'intend',
#  'life',
#  'despite',
#  'clampdown',
#  'authority',
#  'families',
#  'family',
#  'erupt',
#  'open',
#  'warfare',
#  'brother',
#  'fear',
#  'safety',
#  'michael',
#  'refuge',
#  'sicily',
#  'fredo',
#  'corleone',
#  'fredo',
#  'corleone',
#  'shelter',
#  'associate',
#  'moe',
#  'greene',
#  'moe',
#  'greene',
#  'las',
#  'vegas',
#  'las',
#  'vegas',
#  'sonny',
#  'attack',
#  'brother',
#  'law',
#  'carlo',
#  'carlo',
#  'street',
#  'abuse',
#  'sister',
#  'connie',
#  'threaten',
#  'kill',
#  'abuse',
#  'happen',
#  'sonny',
#  'speed',
#  'home',
#  'assassin',
#  'ambush',
#  'highway',
#  'toll',
#  'booth',
#  'riddle',
#  'submachine',
#  'gun',
#  'fire',
#  'michaels',
#  'time',
#  'abroad',
#  'lead',
#  'marriage',
#  'apollonia',
#  'vitelli',
#  'euphoria',
#  'shatter',
#  'car',
#  'bomb',
#  'intend',
#  'life',
#  'devastate',
#  'sonnys',
#  'death',
#  'vito',
#  'decide',
#  'end',
#  'feud',
#  'realise',
#  'tattaglias',
#  'order',
#  'dominant',
#  'don',
#  'emilio',
#  'barzini',
#  'promise',
#  'head',
#  'families',
#  'withdraw',
#  'opposition',
#  'heroin',
#  'business',
#  'forgo',
#  'revenge',
#  'son',
#  'murder',
#  'safety',
#  'guarantee',
#  'michael',
#  'return',
#  'home',
#  'father',
#  'sadden',
#  'involvement',
#  'family',
#  'business',
#  'marry',
#  'kay',
#  'year',
#  'devastate',
#  'sonnys',
#  'death',
#  'vito',
#  'decide',
#  'end',
#  'feud',
#  'realise',
#  'tattaglias',
#  'order',
#  'dominant',
#  'don',
#  'emilio',
#  'barzini',
#  'emilio',
#  'barzini',
#  'promise',
#  'head',
#  'families',
#  'withdraw',
#  'opposition',
#  'heroin',
#  'business',
#  'forgo',
#  'revenge',
#  'son',
#  'murder',
#  'safety',
#  'guarantee',
#  'michael',
#  'return',
#  'home',
#  'father',
#  'sadden',
#  'involvement',
#  'family',
#  'business',
#  'marry',
#  'kay',
#  'year',
#  'father',
#  'end',
#  'career',
#  'survive',
#  'brother',
#  'weak',
#  'michael',
#  'rein',
#  'family',
#  'promise',
#  'kay',
#  'business',
#  'legitimate',
#  'year',
#  'end',
#  'insist',
#  'hagen',
#  'relocate',
#  'las',
#  'vegas',
#  'relinquish',
#  'role',
#  'vito',
#  'tom',
#  'wartime',
#  'consigliere',
#  'old',
#  'man',
#  'agree',
#  'tom',
#  'happen',
#  'come',
#  'battle',
#  'rival',
#  'family',
#  'michael',
#  'travel',
#  'las',
#  'vegas',
#  'buy',
#  'greenes',
#  'stake',
#  'familys',
#  'casino',
#  'greene',
#  'deride',
#  'corleones',
#  'fade',
#  'power',
#  'add',
#  'injury',
#  'insult',
#  'michael',
#  'fredo',
#  'fall',
#  'greenes',
#  'sway',
#  'father',
#  'end',
#  'career',
#  'survive',
#  'brother',
#  'weak',
#  'michael',
#  'rein',
#  'family',
#  'promise',
#  'kay',
#  'business',
#  'legitimate',
#  'year',
#  'end',
#  'insist',
#  'hagen',
#  'relocate',
#  'las',
#  'vegas',
#  'relinquish',
#  'role',
#  'vito',
#  'tom',
#  'wartime',
#  'consigliere',
#  'old',
#  'man',
#  'agree',
#  'tom',
#  'happen',
#  'come',
#  'battle',
#  'rival',
#  'family',
#  'michael',
#  'travel',
#  'las',
#  'vegas',
#  'buy',
#  'greenes',
#  'stake',
#  'familys',
#  'casino',
#  'greene',
#  'deride',
#  'corleones',
#  'fade',
#  'power',
#  'add',
#  'injury',
#  'insult',
#  'michael',
#  'fredo',
#  'fall',
#  'greenes',
#  'sway',
#  'vito',
#  'collapse',
#  'die',
#  'garden',
#  'play',
#  'michaels',
#  'son',
#  'anthony',
#  'funeral',
#  'salvatore',
#  'tessio',
#  'arrange',
#  'meeting',
#  'michael',
#  'don',
#  'barzini',
#  'signal',
#  'treachery',
#  'vito',
#  'warn',
#  'meeting',
#  'set',
#  'day',
#  'christening',
#  'connies',
#  'son',
#  'michael',
#  'stand',
#  'godfather',
#  'christening',
#  'proceed',
#  'corleone',
#  'assassin',
#  'act',
#  'michaels',
#  'order',
#  'murder',
#  'new',
#  'york',
#  'don',
#  'moe',
#  'greene',
#  'tessio',
#  'tell',
#  'michael',
#  'aware',
#  'betrayal',
#  'death',
#  'carlo',
#  'question',
#  'michael',
#  'involvement',
#  'set',
#  'sonnys',
#  'murder',
#  'confess',
#  'contact',
#  'barzini',
#  'peter',
#  'clemenza',
#  'kill',
#  'wire',
#  'garrote',
#  'michael',
#  'confront',
#  'connie',
#  'accuse',
#  'husband',
#  'kill',
#  'deny',
#  'kill',
#  'carlo',
#  'question',
#  'kay',
#  'answer',
#  'accept',
#  'kay',
#  'watch',
#  'warily',
#  'michael',
#  'receive',
#  'capo',
#  'address',
#  'new',
#  'don',
#  'corleone',
#  'vito',
#  'collapse',
#  'die',
#  'garden',
#  'play',
#  'michaels',
#  'son',
#  'anthony',
#  'anthony',
#  'funeral',
#  'salvatore',
#  'tessio',
#  'salvatore',
#  'tessio',
#  'arrange',
#  'meeting',
#  'michael',
#  'don',
#  'barzini',
#  'signal',
#  'treachery',
#  'vito',
#  'warn',
#  'meeting',
#  'set',
#  'day',
#  'christening',
#  'connies',
#  'son',
#  'michael',
#  'stand',
#  'godfather',
#  'christening',
#  'proceed',
#  'corleone',
#  'assassin',
#  'act',
#  'michaels',
#  'order',
#  'murder',
#  'new',
#  'york',
#  'don',
#  'moe',
#  'greene',
#  'tessio',
#  'tell',
#  'michael',
#  'aware',
#  'betrayal',
#  'death',
#  'carlo',
#  'question',
#  'michael',
#  'involvement',
#  'set',
#  'sonnys',
#  'murder',
#  'confess',
#  'contact',
#  'barzini',
#  'peter',
#  'clemenza',
#  'peter',
#  'clemenza',
#  'kill',
#  'wire',
#  'garrote',
#  'garrote',
#  'michael',
#  'confront',
#  'connie',
#  'accuse',
#  'husband',
#  'kill',
#  'deny',
#  'kill',
#  'carlo',
#  'question',
#  'kay',
#  'answer',
#  'accept',
#  'kay',
#  'watch',
#  'warily',
#  'michael',
#  'receive',
#  'capos',
#  'capo',
#  'address',
#  'new',
#  'don',
#  'corleone']

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

series = pd.Series(np.concatenate(movie_plot)).value_counts()[:100]
wordcloud = WordCloud(background_color='white').generate_from_frequencies(series)

plt.figure(figsize=(15,15), facecolor = None)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Building Word Dictionary
#
# In the next step we will build the vocabulary of the corpus in which all the unique words are given IDs and their frequency counds are also stored. You may note that we are using gensim library for building the dictionary.   In gensim, the words are referred as "tokens" adn the index of each word in the dictionary is called ID

# %%
from gensim import corpora

#creating term dictionary
# %time dictionary = corpora.Dictionary(movie_plot)

#filter out terms which occurs in less than 4 documents and more than 20% of the documents.
#NOTE: Since we have smaller dataset, we will keep this commented for now.

#dictionary.filter_extremes(no_below=4, no_above=0.2)

#list of few which which can be further removed
stoplist = set('hello and if this can would should could tell ask stop come go')
stop_ids = [dictionary.token2id[stopword] for stopword in stoplist if stopword in dictionary.token2id]
dictionary.filter_tokens(stop_ids)
# Out:
# Wall time: 98.9 ms

# %% [markdown]
# You can see that there are 2 additional steps performed after creating the dictionary.
# 1. All the tokens in the dictionary which either have occurrred in less than 4 articles or have occurred in more than 20% of the articles are removed from the dictionary, as these words will not be contributing to the various themes or topics.
# 2. Removing content neutral words from the dictionary and additional stopwords.

# %%
#print top 50 items from the dictionary with their unique token-id
dict_tokens = [[[dictionary[key], dictionary.token2id[dictionary[key]]] for key, value in dictionary.items() if key <= 50]]
print (dict_tokens)
# Out:
# [[['abrasive', 0], ['abroad', 1], ['abuse', 2], ['accept', 3], ['accuse', 4], ['act', 5], ['adams', 6], ['add', 7], ['address', 8], ['agree', 9], ['ambush', 10], ['angeles', 11], ['answer', 12], ['anthony', 13], ['apollonia', 14], ['arrange', 15], ['ask', 16], ['assassin', 17], ['assassination', 18], ['associate', 19], ['attack', 20], ['attempt', 21], ['authority', 22], ['aware', 23], ['baron', 24], ['barzini', 25], ['battle', 26], ['bed', 27], ['betrayal', 28], ['bodyguard', 29], ['bomb', 30], ['booth', 31], ['brasi', 32], ['brasis', 33], ['break', 34], ['bronx', 35], ['brother', 36], ['business', 37], ['buy', 38], ['capo', 39], ['capos', 40], ['captain', 41], ['car', 42], ['career', 43], ['carlo', 44], ['casino', 45], ['christening', 46], ['christmas', 47], ['clampdown', 48], ['clemenza', 49], ['collapse', 50]]]

# %% [markdown]
# ### Feature Extraction (Bag of Words)
#
# A bag of words model, or BoW for short is a way of extracting features from text for use in modelling, such as with machine learning algorithms. It is a representation of tet that describes teh occurence of words within a document. It involves two things
#
# 1. A vocabulary of known words
# 2. A measure of the presence of known words
#
# The doc2bow method of dictionary, iterates through all the words in the text, if the word already exists in the corpus, it increments the frequency count, other wise it inserts the word into the corpus and sets it freqeuncy count to 1

# %%
corpus = [dictionary.doc2bow(desc) for desc in movie_plot]

word_frequencies = [[(dictionary[id], frequency) for id, frequency in line] for line in corpus[0:3]]

print(word_frequencies)
# Out:
# [[('abrasive', 2), ('abroad', 2), ('abuse', 4), ('accept', 6), ('accuse', 2), ('act', 2), ('adams', 3), ('add', 2), ('address', 2), ('agree', 2), ('ambush', 2), ('angeles', 2), ('answer', 2), ('anthony', 3), ('apollonia', 2), ('arrange', 2), ('ask', 2), ('assassin', 4), ('assassination', 4), ('associate', 2), ('attack', 4), ('attempt', 4), ('authority', 2), ('aware', 2), ('baron', 2), ('barzini', 7), ('battle', 2), ('bed', 2), ('betrayal', 2), ('bodyguard', 2), ('bomb', 2), ('booth', 2), ('brasi', 3), ('brasis', 2), ('break', 2), ('bronx', 2), ('brother', 6), ('business', 6), ('buy', 2), ('capo', 2), ('capos', 1), ('captain', 2), ('car', 2), ('career', 2), ('carlo', 7), ('casino', 2), ('christening', 4), ('christmas', 2), ('clampdown', 2), ('clemenza', 3), ('collapse', 2), ('come', 4), ('command', 2), ('confess', 2), ('confront', 2), ('connection', 2), ('connie', 4), ('connies', 2), ('consigliere', 5), ('contact', 2), ('corleone', 10), ('corleones', 4), ('corps', 3), ('coveted', 2), ('crime', 2), ('daughter', 2), ('day', 4), ('deal', 2), ('dealer', 2), ('death', 4), ('decide', 2), ('deny', 2), ('deride', 2), ('despite', 2), ('devastate', 2), ('die', 2), ('disapprove', 2), ('dispatch', 2), ('dispute', 2), ('dominant', 2), ('don', 11), ('drug', 6), ('eld', 2), ('emerge', 2), ('emilio', 3), ('end', 6), ('enforcer', 2), ('erupt', 2), ('euphoria', 2), ('fade', 2), ('fall', 2), ('families', 4), ('family', 13), ('familys', 2), ('father', 8), ('fear', 2), ('feud', 2), ('fire', 2), ('fish', 4), ('fontane', 3), ('forgo', 2), ('fredo', 5), ('funeral', 2), ('garden', 2), ('garrote', 3), ('girlfriend', 2), ('godfather', 4), ('godson', 2), ('greene', 7), ('greenes', 4), ('guarantee', 2), ('gun', 2), ('hagen', 7), ('handgun', 2), ('happen', 4), ('head', 6), ('hear', 2), ('help', 2), ('heroin', 2), ('highway', 2), ('hit', 2), ('home', 4), ('hospital', 4), ('husband', 2), ('impart', 2), ('influence', 2), ('injury', 2), ('insist', 2), ('insult', 2), ('intend', 2), ('introduce', 2), ('investment', 2), ('involvement', 4), ('jack', 3), ('jaw', 2), ('johnny', 3), ('kay', 11), ('kidnap', 2), ('kill', 10), ('land', 2), ('las', 7), ('law', 2), ('lead', 2), ('legitimate', 2), ('life', 2), ('los', 2), ('luca', 3), ('man', 4), ('marine', 3), ('marriage', 2), ('marry', 2), ('mccluskey', 4), ('meet', 2), ('meeting', 4), ('michael', 31), ('michaels', 6), ('moe', 5), ('morning', 2), ('movie', 2), ('murder', 8), ('new', 6), ('offer', 2), ('old', 2), ('open', 2), ('opposition', 2), ('order', 4), ('peter', 3), ('plan', 2), ('plant', 2), ('play', 2), ('plead', 2), ('police', 2), ('political', 2), ('popular', 2), ('power', 2), ('pressure', 2), ('pretext', 2), ('prize', 1), ('prized', 1), ('proceed', 2), ('promise', 4), ('protection', 2), ('question', 4), ('realise', 2), ('receive', 4), ('reception', 2), ('refuge', 2), ('rein', 2), ('relinquish', 2), ('relocate', 2), ('request', 2), ('restaurant', 2), ('retaliate', 2), ('retrieve', 2), ('return', 2), ('revenge', 2), ('riddle', 2), ('rival', 4), ('role', 6), ('sadden', 2), ('safety', 4), ('salvatore', 3), ('second', 2), ('secure', 2), ('send', 2), ('set', 4), ('settle', 2), ('sever', 2), ('shatter', 2), ('shelter', 2), ('shortly', 2), ('sicily', 2), ('signal', 2), ('singer', 2), ('sister', 2), ('sleep', 2), ('sollozzo', 7), ('sollozzos', 4), ('son', 12), ('sonny', 11), ('sonnys', 4), ('speed', 2), ('sprawl', 2), ('spy', 2), ('stake', 2), ('stallion', 3), ('stand', 2), ('street', 2), ('studio', 2), ('submachine', 2), ('survive', 2), ('sway', 2), ('tattaglias', 6), ('tell', 2), ('tessio', 5), ('threaten', 2), ('thwart', 2), ('time', 2), ('toll', 2), ('tom', 7), ('trade', 2), ('travel', 2), ('treachery', 2), ('turk', 3), ('uniform', 2), ('unmove', 2), ('vegas', 7), ('vest', 2), ('virgil', 3), ('vitelli', 2), ('vito', 19), ('vitos', 4), ('wake', 2), ('warfare', 2), ('warily', 2), ('warn', 2), ('wartime', 2), ('watch', 2), ('weak', 2), ('wedding', 2), ('wire', 2), ('withdraw', 2), ('woltz', 5), ('wrap', 2), ('year', 4), ...

# %% [markdown]
# The above results shows vocabulary with their frequency.

# %% [markdown]
# ### Build Tf-Idf and LSI Model
#
# Tf-Idf means, Term frequency-Inverse Document Frequency. it is a commonly used NLP model that helps you determine the most important words in each document in the corpus. Once the Tf-Idf is build, pass it to LSI model and specify the num of features to build

# %%
# %time movie_tfidf_model = gensim.models.TfidfModel(corpus, id2word=dictionary)
# latent semantic indexing (Lsi)
# %time movie_lsi_model = gensim.models.LsiModel(movie_tfidf_model[corpus], id2word=dictionary, num_topics=300)
# Out:
# Wall time: 40 ms
# Wall time: 1.4 s

# %%
movie_tfidf_model[corpus][0]
# Out:
# [(0, 0.04511056281609457),
#  (1, 0.03832074655163021),
#  (2, 0.0520982774123676),
#  (3, 0.04318922482063948),
#  (4, 0.022555281408047283),
#  (5, 0.016797538219705026),
#  (6, 0.057481119827445325),
#  (7, 0.031530930287165866),
#  (8, 0.02755914238566762),
#  (9, 0.00826722212932861),
#  (10, 0.021621657746068817),
#  (11, 0.02474111402270152),
#  (12, 0.02474111402270152),
#  (13, 0.05152343797519796),
#  (14, 0.04511056281609457),
#  (15, 0.016797538219705026),
#  (16, 0.005168497361499379),
#  (17, 0.07664149310326042),
#  (18, 0.05869019534502327),
#  (19, 0.02474111402270152),
#  (20, 0.02358735448416938),
#  (21, 0.013579632528928697),
#  (22, 0.0260491387061838),
#  (23, 0.029345097672511634),
#  (24, 0.031530930287165866),
#  (25, 0.157886969856331),
#  (26, 0.017357441136179354),
#  (27, 0.016797538219705026),
#  (28, 0.031530930287165866),
#  (29, 0.034348958650131975),
#  (30, 0.031530930287165866),
#  (31, 0.034348958650131975),
#  (32, 0.06766584422414186),
#  (33, 0.04511056281609457),
#  (34, 0.008975648879118584),
#  (35, 0.03832074655163021),
#  (36, 0.047296395430748796),
#  (37, 0.057777967325158344),
#  (38, 0.016267915495049707),
#  (39, 0.03832074655163021),
#  (40, 0.022555281408047283),
#  (41, 0.01795129775823717),
#  (42, 0.012825750318206782),
#  (43, 0.01795129775823717),
#  (44, 0.13412261293070574),
#  (45, 0.03832074655163021),
#  (46, 0.09022112563218913),
#  (47, 0.02474111402270152),
#  (48, 0.04511056281609457),
#  (49, 0.057481119827445325),
#  (50, 0.021621657746068817),
#  (51, 0.013579632528928697),
#  (52, 0.019985257032190305),
#  (53, 0.015765465143582933),
#  (54, 0.015287534540221207),
#  (55, 0.02755914238566762),
#  (56, 0.06869791730026395),
#  (57, 0.04511056281609457),
#  (58, 0.09580186637907553),
#  (59, 0.031530930287165866),
#  (60, 0.19160373275815107),
#  (61, 0.07664149310326042),
#  (62, 0.05152343797519796),
#  (63, 0.04511056281609457),
#  (64, 0.020769326121203274),
#  (65, 0.014831841481604465),
#  (66, 0.011012622658174228),
#  (67, 0.01795129775823717),
#  (68, 0.03832074655163021),
#  (69, 0.015213184018164287),
#  (70, 0.007606592009082144),
#  (71, 0.02474111402270152),
#  (72, 0.034348958650131975),
#  (73, 0.01147248013048049),
#  (74, 0.029345097672511634),
#  (75, 0.007189693592274576),
#  (76, 0.03832074655163021),
#  (77, 0.03832074655163021),
#  (78, 0.034348958650131975),
#  (79, 0.04511056281609457),
#  (80, 0.1515752831211719),
#  (81, 0.07076206345250813),
#  (82, 0.031530930287165866),
#  (83, 0.022555281408047283),
#  (84, 0.06766584422414186),
#  (85, 0.020369448793393048),
#  (86, 0.03832074655163021),
#  (87, 0.029345097672511634),
#  (88, 0.04511056281609457),
#  (89, 0.029345097672511634),
#  (90, 0.010567624871715002),
#  (91, 0.09022112563218913),
#  (92, 0.07457112084812319),
#  (93, 0.02474111402270152),
#  (94, 0.036894611464910854),
#  (95, 0.016267915495049707),
#  (96, 0.03832074655163021),
#  (97, 0.012125764442918671),
#  (98, 0.06869791730026395),
#  (99, 0.06766584422414186),
#  (100, 0.03832074655163021),
#  (101, 0.09580186637907553),
#  (102, 0.020769326121203274),
#  (103, 0.029345097672511634),
#  (104, 0.06766584422414186),
#  (105, 0.020769326121203274),
#  (106, 0.09022112563218913),
#  (107, 0.04511056281609457),
#  (108, 0.1202213552754619),
#  (109, 0.09022112563218913),
#  (110, 0.04511056281609457),
#  (111, 0.013579632528928697),
#  (112, 0.1202213552754619),
#  (113, 0.03832074655163021),
#  (114, 0.027159265057857394),
#  (115, 0.03170287461514501),
#  (116, 0.010283673562600865),
#  (117, 0.0069877145962730335),
#  (118, 0.031530930287165866),
#  (119, 0.029345097672511634),
#  (120, 0.019985257032190305),
#  (121, 0.012438070704286654),
#  (122, 0.0385186448834389),
#  (123, 0.016797538219705026),
#  (124, 0.04511056281609457),
#  (125, 0.034348958650131975),
#  (126, 0.023587354484169376),
#  (127, 0.015765465143582933),
#  (128, 0.020769326121203274),
#  (129, 0.01795129775823717),
#  (130, 0.01925932244171945),
#  (131, 0.031530930287165866),
#  (132, 0.05869019534502327),
#  (133, 0.028888983662579172),
#  (134, 0.04511056281609457),
#  (135, 0.047296395430748796),
#  (136, 0.21076410603396617),
#  (137, 0.029345097672511634),
#  (138, 0.021098959443036868),
#  (139, 0.01795129775823717),
#  (140, 0.13412261293070574),
#  (141, 0.023587354484169376),
#  (142, 0.010567624871715002),
#  (143, 0.04511056281609457),
#  (144, 0.007606592009082144),
#  (145, 0.023587354484169376),
#  (146, 0.06766584422414186),
#  (147, 0.005899030721428457),
#  (148, 0.047296395430748796),
#  (149, 0.013579632528928697),
#  (150, 0.01179367724208469),
#  (151, 0.09022112563218913),
#  (152, 0.00484194598124409),
#  (153, 0.03716698701309808),
#  (154, 0.38348726735187355),
#  (155, 0.09459279086149759),
#  (156, 0.09580186637907553),
#  (157, 0.012125764442918671),
#  (158, 0.029345097672511634),
#  (159, 0.05431853011571479),
#  (160, 0.01756857780745764),
#  (161, 0.010007721955240677),
#  (162, 0.008497718275756856),
#  (163, 0.010567624871715002),
#  (164, 0.03832074655163021),
#  (165, 0.016995436551513712),
#  (166, 0.03243248661910323),
#  (167, 0.008733769077425122),
#  (168, 0.02755914238566762),
#  (169, 0.010283673562600865),
#  (170, 0.034348958650131975),
#  (171, 0.01147248013048049),
#  (172, 0.02474111402270152),
#  (173, 0.029345097672511634),
#  (174, 0.01925932244171945),
#  (175, 0.02474111402270152),
#  (176, 0.031530930287165866),
#  (177, 0.022555281408047283),
#  (178, 0.022555281408047283),
#  (179, 0.0260491387061838),
#  (180, 0.027159265057857394),
#  (181, 0.031530930287165866),
#  (182, 0.03590259551647434),
#  (183, 0.031530930287165866),
#  (184, 0.030575069080442413),
#  (185, 0.034348958650131975),
#  (186, 0.03832074655163021),
#  (187, 0.04511056281609457),
#  (188, 0.04511056281609457),
#  (189, 0.03832074655163021),
#  (190, 0.021621657746068817),
#  (191, 0.031530930287165866),
#  (192, 0.031530930287165866),
#  (193, 0.022555281408047283),
#  (194, 0.003082791352030158),
#  (195, 0.021621657746068817),
#  (196, 0.04511056281609457),
#  (197, 0.0520982774123676),
#  (198, 0.07814741611855139),
#  (199, 0.04511056281609457),
#  (200, 0.05511828477133524),
#  (201, 0.05152343797519796),
#  (202, 0.013195440767725958),
#  (203, 0.02474111402270152),
#  (204, 0.012469506177255103),
#  (205, 0.021135249743430003),
#  (206, 0.02755914238566762),
#  (207, 0.031530930287165866),
#  (208, 0.03832074655163021),
#  (209, 0.031530930287165866),
#  (210, 0.022555281408047283),
#  (211, 0.034348958650131975),
#  (212, 0.02755914238566762),
#  (213, 0.02474111402270152),
#  (214, 0.015287534540221207),
#  (215, 0.02755914238566762),
#  (216, 0.157886969856331),
#  (217, 0.09022112563218913),
#  (218, 0.07917264460635576),
#  (219, 0.21076410603396617),
#  (220, 0.09022112563218913),
#  (221, 0.02474111402270152),
#  (222, 0.04511056281609457),
#  (223, 0.02474111402270152),
#  (224, 0.03832074655163021),
#  (225, 0.057481119827445325),
#  (226, 0.016797538219705026),
#  (227, 0.016797538219705026),
#  (228, 0.02474111402270152),
#  (229, 0.04511056281609457),
#  (230, 0.01925932244171945),
#  (231, 0.03832074655163021),
#  (232, 0.13533168844828372),
#  (233, 0.0032179056907763294),
#  (234, 0.09580186637907553),
#  (235, 0.015765465143582933),
#  (236, 0.03832074655163021),
#  (237, 0.006595836970216757),
#  (238, 0.034348958650131975),
#  (239, 0.06994839961266607),
#  (240, 0.031530930287165866),
#  (241, 0.016267915495049707),
#  (242, 0.034348958650131975),
#  (243, 0.06766584422414186),
#  (244, 0.02755914238566762),
#  (245, 0.04511056281609457),
#  (246, 0.13412261293070574),
#  (247, 0.03832074655163021),
#  (248, 0.06766584422414186),
#  (249, 0.04511056281609457),
#  (250, 0.364047092240487),
#  (251, 0.09022112563218913),
#  (252, 0.021621657746068817),
#  (253, 0.04511056281609457),
#  (254, 0.04511056281609457),
#  (255, 0.01925932244171945),
#  (256, 0.03832074655163021),
#  (257, 0.010567624871715002),
#  (258, 0.03832074655163021),
#  (259, 0.020769326121203274),
#  (260, 0.034348958650131975),
#  (261, 0.031530930287165866),
#  (262, 0.1127764070402364),
#  (263, 0.04511056281609457),
#  (264, 0.013975429192546067),
#  (265, 0.031530930287165866),
#  (266, 0.008042025217140118)]

# %%
movie_lsi_model[movie_tfidf_model[corpus]][0]
# Out:
# [(0, 0.33034479326981836),
#  (1, -0.7432468223115963),
#  (2, 0.1372076090257664),
#  (3, -0.057563902262990956),
#  (4, 0.005530352515512616),
#  (5, -0.0837002690356445),
#  (6, 0.030825994155058725),
#  (7, -0.018522517088886532),
#  (8, 0.19730610156386752),
#  (9, -0.05988788950160539),
#  (10, 0.026250830566849837),
#  (11, -0.03643517847278878),
#  (12, 0.006204861612268101),
#  (13, -0.014299461377291068),
#  (14, 0.014759739190239539),
#  (15, -0.015608173133803799),
#  (16, 0.031806281542428046),
#  (17, -0.010937366918832446),
#  (18, 0.02147485812999013),
#  (19, -0.021735608144740792),
#  (20, -0.013741749915096132),
#  (21, 0.005708269665699542),
#  (22, 0.008341759251761269),
#  (23, 0.01070197136156719),
#  (24, -0.01450611623913294),
#  (25, -0.009737521727265757),
#  (26, -0.003603389827845441),
#  (27, -0.00281063849288189),
#  (28, 0.021032615505276256),
#  (29, 0.0013599491158000074),
#  (30, 0.0033351687933761242),
#  (31, -0.0033052724116560996),
#  (32, -0.017184549289799688),
#  (33, -0.019845522022568753),
#  (34, -0.012268007229460563),
#  (35, 0.015286568407158887),
#  (36, 0.010232339357947852),
#  (37, 0.011568743755920534),
#  (38, 0.014273078839987305),
#  (39, 0.005697343786947092),
#  (40, 0.025480442565927856),
#  (41, 0.02881816376121599),
#  (42, -0.01108060854529574),
#  (43, -0.0026282304447538727),
#  (44, -0.013662522973736019),
#  (45, -0.009403027212570138),
#  (46, -0.006921730614747985),
#  (47, -0.013802831300245509),
#  (48, -0.013538848305568455),
#  (49, -0.02661139116260398),
#  (50, -0.004030788366472857),
#  (51, 0.008465114752423378),
#  (52, 0.029134081851819173),
#  (53, 0.028183665305728453),
#  (54, 0.005477858226133986),
#  (55, 0.004982884449774556),
#  (56, -0.00305174443179719),
#  (57, -0.0029361964524091577),
#  (58, -0.015596280717556426),
#  (59, -0.016965450488093496),
#  (60, -0.026383339443733906),
#  (61, -0.006853605088792972),
#  (62, 0.002817333998650306),
#  (63, 0.01817577449817285),
#  (64, 0.03119758936032925),
#  (65, 0.037207677336299406),
#  (66, 0.0260101804308589),
#  (67, -0.0017257145327979773),
#  (68, -0.027372139955983935),
#  (69, -0.009024918418726392),
#  (70, 0.001032076845368935),
#  (71, 0.01820690432252463),
#  (72, 0.0035384531526020248),
#  (73, 0.019122431766395886),
#  (74, -8.373826130242848e-05),
#  (75, -0.015150969302754133),
#  (76, -0.008361879256998796),
#  (77, -0.0007397209594094474),
#  (78, 0.01823884739279645),
#  (79, -0.01213756589985542),
#  (80, -0.0038888714673150997),
#  (81, -0.022192520940486123),
#  (82, 0.016297868822034812),
#  (83, 0.052790037062629136),
#  (84, -0.026221343114909746),
#  (85, 0.02531965999674738),
#  (86, -0.021491154038595923),
#  (87, 0.03390742474573241),
#  (88, -0.016133884077969896),
#  (89, 0.006245061479368912),
#  (90, -0.008237941790339346),
#  (91, 0.008205695765601592),
#  (92, -0.009518585128012262),
#  (93, 0.017677349063451645),
#  (94, -0.013143881104559024),
#  (95, 0.05965895783806764),
#  (96, 0.007363119848692093),
#  (97, -0.02267977162285993),
#  (98, 0.01435277325414312),
#  (99, -0.4840510941504894)]

# %% [markdown]
# Serialize and Store the corpus locally for easy retrival whenver required.

# %%
# %time gensim.corpora.MmCorpus.serialize('movie_tfidf_model_mm', movie_tfidf_model[corpus])
# %time gensim.corpora.MmCorpus.serialize('movie_lsi_model_mm',movie_lsi_model[movie_tfidf_model[corpus]])
# Out:
# Wall time: 220 ms
# Wall time: 178 ms

# %%
#Load the indexed corpus
movie_tfidf_corpus = gensim.corpora.MmCorpus('movie_tfidf_model_mm')
movie_lsi_corpus = gensim.corpora.MmCorpus('movie_lsi_model_mm')

print(movie_tfidf_corpus)
print(movie_lsi_corpus)
# Out:
# MmCorpus(100 documents, 8422 features, 26005 non-zero entries)
# MmCorpus(100 documents, 100 features, 10000 non-zero entries)

# %%
from gensim.similarities import MatrixSimilarity

# %time movie_index = MatrixSimilarity(movie_lsi_corpus, num_features = movie_lsi_corpus.num_terms)
# Out:
# Wall time: 40 ms

# %% [markdown]
# ## Time for Semantic Search
#
# Now comes the fun part. With the index of movies initialized and loaded, we can use it to find similar movies based
#
#
# We will input a search query and model will return relevant movie titles with "Relevance %" which is the similarity score. The higher the similarity score, the more similar the query to the documetn at the given index

# %% [markdown]
# Below is the helper function to search the index, sort and return the results

# %%
from operator import itemgetter

def search_similar_movies(search_term):

    query_bow = dictionary.doc2bow(spacy_tokenizer(search_term))
    query_tfidf = movie_tfidf_model[query_bow]
    query_lsi = movie_lsi_model[query_tfidf]

    movie_index.num_best = 5

    movies_list = movie_index[query_lsi]
    print(movies_list)
    movies_list.sort(key=itemgetter(1), reverse=True)
    movie_names = []

    for j, movie in enumerate(movies_list):

        movie_names.append (
            {
                'Relevance': round((movie[1] * 100),2),
                'Movie Title': df_movies['title'][movie[0]],
                'Movie Plot': df_movies['wiki_plot'][movie[0]]
            }

        )
        if j == (movie_index.num_best-1):
            break

    return pd.DataFrame(movie_names, columns=['Relevance','Movie Title','Movie Plot'])

# %%
# search for movie tiles that are related to below search parameters
search_similar_movies('crime and drugs ')
# Out:
# [(59, 0.8187194466590881), (63, 0.3338950276374817), (0, 0.32354995608329773), (91, 0.29042744636535645), (15, 0.13237877190113068)]
#    Relevance            Movie Title  \
# 0      81.87             Goodfellas
# 1      33.39  The French Connection
# 2      32.35          The Godfather
# 3      29.04     A Clockwork Orange
# 4      13.24      On the Waterfront
#
#                                           Movie Plot
# 0  Henry Hill (Liotta) admits, "As far back as I ...
# 1  In Marseille, an undercover detective is follo...
# 2  On the day of his only daughter's wedding, Vit...
# 3  In futuristic London, Alex DeLarge is the lead...
# 4  Mob-connected union boss Johnny Friendly (Lee ...

# %% [markdown]
# The model returns movie titles with "Relevance %". Definitely, the top list movies are related to crimes and drugs.

# %%
# search for movie tiles that are related to below search parameters
search_similar_movies('violence protest march')
# Out:
# [(32, 0.7396256923675537), (91, 0.5228461623191833), (30, 0.27100956439971924), (62, 0.24673134088516235), (44, 0.18350934982299805)]
#    Relevance                     Movie Title  \
# 0      73.96                          Gandhi
# 1      52.28              A Clockwork Orange
# 2      27.10                         Amadeus
# 3      24.67  All Quiet on the Western Front
# 4      18.35     The Best Years of Our Lives
#
#                                           Movie Plot
# 0  The screenplay of Gandhi is available as a pub...
# 1  In futuristic London, Alex DeLarge is the lead...
# 2  The story begins in 1823 as the elderly Antoni...
# 3  \n\n\n\n\nThis section's plot summary may be t...
# 4  After World War II, Fred Derry (Dana Andrews),...

# %% [markdown]
# Here the top most movie title "Gandhi" is surely related to non-violence protests

# %%
# search for movie tiles that are related to below search parameters
search_similar_movies('love affair hate')
# Out:
# [(74, 0.45189785957336426), (84, 0.44434070587158203), (35, 0.30465301871299744), (72, 0.2895485758781433), (93, 0.2835497558116913)]
#    Relevance            Movie Title  \
# 0      45.19    Terms of Endearment
# 1      44.43           The Graduate
# 2      30.47  From Here to Eternity
# 3      28.95          Out of Africa
# 4      28.35      Wuthering Heights
#
#                                           Movie Plot
# 0  Aurora Greenway (Shirley MacLaine) and her dau...
# 1  Benjamin Braddock, going on from twenty to twe...
# 2  In 1941, bugler and career soldier Private Rob...
# 3  The story begins in 1913 in Denmark, when Kare...
# 4  A traveller named Lockwood (Miles Mander) is c...

# %% [markdown]
# ### Closing Notes
#
# In general usage, computing semantic relationships between textual data enables to recommend articles or products related to given query, to follow trends, to explore a specific subject in more details.
#
# In this article we saw the basic version of how semantic search can be implemented. There are many ways to further enhance it using deep learning models.
#
# ###################################################################################################################################
#
# ### This was just an attempt to showcase my learning journey into field of NLP and Machine Learning.
# ### Your valuable feedback, comments and suggestions are welcomed !
# ### Hope you all like it and vote for it.
